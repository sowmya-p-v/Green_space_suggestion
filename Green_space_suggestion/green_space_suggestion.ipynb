# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/metadata.zip ./

# %%
# !unzip metadata.zip
# Out:
# Archive:  metadata.zip
#   inflating: class_dict.csv
#   inflating: metadata.csv
#   inflating: train/100694_mask.png
#   inflating: train/100694_sat.jpg
#   inflating: train/102122_mask.png
#   inflating: train/102122_sat.jpg
#   inflating: train/10233_mask.png
#   inflating: train/10233_sat.jpg
#   inflating: train/103665_mask.png
#   inflating: train/103665_sat.jpg
#   inflating: train/103730_mask.png
#   inflating: train/103730_sat.jpg
#   inflating: train/104113_mask.png
#   inflating: train/104113_sat.jpg
#   inflating: train/10452_mask.png
#   inflating: train/10452_sat.jpg
#   inflating: train/10901_mask.png
#   inflating: train/10901_sat.jpg
#   inflating: train/111335_mask.png
#   inflating: train/111335_sat.jpg
#   inflating: train/114433_mask.png
#   inflating: train/114433_sat.jpg
#   inflating: train/114473_mask.png
#   inflating: train/114473_sat.jpg
#   inflating: train/114577_mask.png
#   inflating: train/114577_sat.jpg
#   inflating: train/115444_mask.png
#   inflating: train/115444_sat.jpg
#   inflating: train/119_mask.png
#   inflating: train/119_sat.jpg
#   inflating: train/119012_mask.png
#   inflating: train/119012_sat.jpg
#   inflating: train/119079_mask.png
#   inflating: train/119079_sat.jpg
#   inflating: train/120245_mask.png
#   inflating: train/120245_sat.jpg
#   inflating: train/120625_mask.png
#   inflating: train/120625_sat.jpg
#   inflating: train/122104_mask.png
#   inflating: train/122104_sat.jpg
#   inflating: train/122178_mask.png
#   inflating: train/122178_sat.jpg
#   inflating: train/123172_mask.png
#   inflating: train/123172_sat.jpg
#   inflating: train/124529_mask.png
#   inflating: train/124529_sat.jpg
#   inflating: train/125510_mask.png
#   inflating: train/125510_sat.jpg
#   inflating: train/125795_mask.png
#   inflating: train/125795_sat.jpg
#   inflating: train/126796_mask.png
#   inflating: train/126796_sat.jpg
#   inflating: train/127660_mask.png
#   inflating: train/127660_sat.jpg
#   inflating: train/127976_mask.png
#   inflating: train/127976_sat.jpg
#   inflating: train/129297_mask.png
#   inflating: train/129297_sat.jpg
#   inflating: train/129298_mask.png
#   inflating: train/129298_sat.jpg
#   inflating: train/131720_mask.png
#   inflating: train/131720_sat.jpg
#   inflating: train/133209_mask.png
#   inflating: train/133209_sat.jpg
#   inflating: train/133254_mask.png
#   inflating: train/133254_sat.jpg
#   inflating: train/13415_mask.png
#   inflating: train/13415_sat.jpg
#   inflating: train/134465_mask.png
#   inflating: train/134465_sat.jpg
#   inflating: train/136252_mask.png
#   inflating: train/136252_sat.jpg
#   inflating: train/137499_mask.png
#   inflating: train/137499_sat.jpg
#   inflating: train/137806_mask.png
#   inflating: train/137806_sat.jpg
#   inflating: train/139482_mask.png
#   inflating: train/139482_sat.jpg
#   inflating: train/139581_mask.png
#   inflating: train/139581_sat.jpg
#   inflating: train/140299_mask.png
#   inflating: train/140299_sat.jpg
#   inflating: train/141685_mask.png
#   inflating: train/141685_sat.jpg
#   inflating: train/142766_mask.png
#   inflating: train/142766_sat.jpg
#   inflating: train/143353_mask.png
#   inflating: train/143353_sat.jpg
#   inflating: train/143364_mask.png
#   inflating: train/143364_sat.jpg
#   inflating: train/143794_mask.png
#   inflating: train/143794_sat.jpg
#   inflating: train/147545_mask.png
#   inflating: train/147545_sat.jpg
#   inflating: train/147716_mask.png
#   inflating: train/147716_sat.jpg
#   inflating: train/148260_mask.png
#   inflating: train/148260_sat.jpg
#   inflating: train/148381_mask.png
#   inflating: train/148381_sat.jpg
#   inflating: train/149624_mask.png
#   inflating: train/149624_sat.jpg
#   inflating: train/152569_mask.png
#   inflating: train/152569_sat.jpg
#   inflating: train/154124_mask.png
#   inflating: train/154124_sat.jpg
#   inflating: train/154626_mask.png
#   inflating: train/154626_sat.jpg
#   inflating: train/155165_mask.png
#   inflating: train/155165_sat.jpg
#   inflating: train/15573_mask.png
#   inflating: train/15573_sat.jpg
#   inflating: train/156574_mask.png
#   inflating: train/156574_sat.jpg
#   inflating: train/156951_mask.png
#   inflating: train/156951_sat.jpg
#   inflating: train/157839_mask.png
#   inflating: train/157839_sat.jpg
#   inflating: train/158163_mask.png
#   inflating: train/158163_sat.jpg
#   inflating: train/159177_mask.png
#   inflating: train/159177_sat.jpg
#   inflating: train/159280_mask.png
#   inflating: train/159280_sat.jpg
#   inflating: train/159322_mask.png
#   inflating: train/159322_sat.jpg
#   inflating: train/160037_mask.png
#   inflating: train/160037_sat.jpg
#   inflating: train/161109_mask.png
#   inflating: train/161109_sat.jpg
#   inflating: train/161838_mask.png
#   inflating: train/161838_sat.jpg
#   inflating: train/162310_mask.png
#   inflating: train/162310_sat.jpg
#   inflating: train/164029_mask.png
#   inflating: train/164029_sat.jpg
#   inflating: train/16453_mask.png
#   inflating: train/16453_sat.jpg
#   inflating: train/166293_mask.png
#   inflating: train/166293_sat.jpg
#   inflating: train/166805_mask.png
#   inflating: train/166805_sat.jpg
#   inflating: train/168514_mask.png
#   inflating: train/168514_sat.jpg
#   inflating: train/170535_mask.png
#   inflating: train/170535_sat.jpg
#   inflating: train/172307_mask.png
#   inflating: train/172307_sat.jpg
#   inflating: train/172854_mask.png
#   inflating: train/172854_sat.jpg
#   inflating: train/174980_mask.png
#   inflating: train/174980_sat.jpg
#   inflating: train/176112_mask.png
#   inflating: train/176112_sat.jpg
#   inflating: train/176225_mask.png
#   inflating: train/176225_sat.jpg
#   inflating: train/176506_mask.png
#   inflating: train/176506_sat.jpg
#   inflating: train/180902_mask.png
#   inflating: train/180902_sat.jpg
#   inflating: train/181447_mask.png
#   inflating: train/181447_sat.jpg
#   inflating: train/182027_mask.png
#   inflating: train/182027_sat.jpg
#   inflating: train/182422_mask.png
#   inflating: train/182422_sat.jpg
#   inflating: train/185522_mask.png
#   inflating: train/185522_sat.jpg
#   inflating: train/185562_mask.png
#   inflating: train/185562_sat.jpg
#   inflating: train/186739_mask.png
#   inflating: train/186739_sat.jpg
#   inflating: train/192576_mask.png
#   inflating: train/192576_sat.jpg
#   inflating: train/192602_mask.png
#   inflating: train/192602_sat.jpg
#   inflating: train/192918_mask.png
#   inflating: train/192918_sat.jpg
#   inflating: train/194156_mask.png
#   inflating: train/194156_sat.jpg
#   inflating: train/195769_mask.png
#   inflating: train/195769_sat.jpg
#   inflating: train/19627_mask.png
#   inflating: train/19627_sat.jpg
#   inflating: train/200561_mask.png
#   inflating: train/200561_sat.jpg
#   inflating: train/200589_mask.png
#   inflating: train/200589_sat.jpg
#   inflating: train/20187_mask.png
#   inflating: train/20187_sat.jpg
#   inflating: train/202277_mask.png
#   inflating: train/202277_sat.jpg
#   inflating: train/204494_mask.png
#   inflating: train/204494_sat.jpg
#   inflating: train/204562_mask.png
#   inflating: train/204562_sat.jpg
#   inflating: train/207663_mask.png
#   inflating: train/207663_sat.jpg
#   inflating: train/207743_mask.png
#   inflating: train/207743_sat.jpg
#   inflating: train/208495_mask.png
#   inflating: train/208495_sat.jpg
#   inflating: train/208695_mask.png
#   inflating: train/208695_sat.jpg
#   inflating: train/209787_mask.png
#   inflating: train/209787_sat.jpg
#   inflating: train/21023_mask.png
#   inflating: train/21023_sat.jpg
#   inflating: train/210436_mask.png
#   inflating: train/210436_sat.jpg
#   inflating: train/210473_mask.png
#   inflating: train/210473_sat.jpg
#   inflating: train/210669_mask.png
#   inflating: train/210669_sat.jpg
#   inflating: train/211316_mask.png
#   inflating: train/211316_sat.jpg
#   inflating: train/211739_mask.png
#   inflating: train/211739_sat.jpg
#   inflating: train/215525_mask.png
#   inflating: train/215525_sat.jpg
#   inflating: train/217085_mask.png
#   inflating: train/217085_sat.jpg
#   inflating: train/21717_mask.png
#   inflating: train/21717_sat.jpg
#   inflating: train/218329_mask.png
#   inflating: train/218329_sat.jpg
#   inflating: train/219555_mask.png
#   inflating: train/219555_sat.jpg
#   inflating: train/219670_mask.png
#   inflating: train/219670_sat.jpg
#   inflating: train/221278_mask.png
#   inflating: train/221278_sat.jpg
#   inflating: train/225393_mask.png
#   inflating: train/225393_sat.jpg
#   inflating: train/225945_mask.png
#   inflating: train/225945_sat.jpg
#   inflating: train/226788_mask.png
#   inflating: train/226788_sat.jpg
#   inflating: train/229383_mask.png
#   inflating: train/229383_sat.jpg
#   inflating: train/232373_mask.png
#   inflating: train/232373_sat.jpg
#   inflating: train/2334_mask.png
#   inflating: train/2334_sat.jpg
#   inflating: train/233615_mask.png
#   inflating: train/233615_sat.jpg
#   inflating: train/234269_mask.png
#   inflating: train/234269_sat.jpg
#   inflating: train/235869_mask.png
#   inflating: train/235869_sat.jpg
#   inflating: train/238322_mask.png
#   inflating: train/238322_sat.jpg
#   inflating: train/239955_mask.png
#   inflating: train/239955_sat.jpg
#   inflating: train/242583_mask.png
#   inflating: train/242583_sat.jpg
#   inflating: train/244423_mask.png
#   inflating: train/244423_sat.jpg
#   inflating: train/245846_mask.png
#   inflating: train/245846_sat.jpg
#   inflating: train/246378_mask.png
#   inflating: train/246378_sat.jpg
#   inflating: train/247179_mask.png
#   inflating: train/247179_sat.jpg
#   inflating: train/24813_mask.png
#   inflating: train/24813_sat.jpg
#   inflating: train/252743_mask.png
#   inflating: train/252743_sat.jpg
#   inflating: train/253691_mask.png
#   inflating: train/253691_sat.jpg
#   inflating: train/254565_mask.png
#   inflating: train/254565_sat.jpg
#   inflating: train/255711_mask.png
#   inflating: train/255711_sat.jpg
#   inflating: train/255876_mask.png
#   inflating: train/255876_sat.jpg
#   inflating: train/255889_mask.png
#   inflating: train/255889_sat.jpg
#   inflating: train/256189_mask.png
#   inflating: train/256189_sat.jpg
#   inflating: train/257695_mask.png
#   inflating: train/257695_sat.jpg
#   inflating: train/26261_mask.png
#   inflating: train/26261_sat.jpg
#   inflating: train/262885_mask.png
#   inflating: train/262885_sat.jpg
#   inflating: train/263576_mask.png
#   inflating: train/263576_sat.jpg
#   inflating: train/264436_mask.png
#   inflating: train/264436_sat.jpg
#   inflating: train/266_mask.png
#   inflating: train/266_sat.jpg
#   inflating: train/267065_mask.png
#   inflating: train/267065_sat.jpg
#   inflating: train/267163_mask.png
#   inflating: train/267163_sat.jpg
#   inflating: train/268881_mask.png
#   inflating: train/268881_sat.jpg
#   inflating: train/269601_mask.png
#   inflating: train/269601_sat.jpg
#   inflating: train/271245_mask.png
#   inflating: train/271245_sat.jpg
#   inflating: train/271609_mask.png
#   inflating: train/271609_sat.jpg
#   inflating: train/271941_mask.png
#   inflating: train/271941_sat.jpg
#   inflating: train/273002_mask.png
#   inflating: train/273002_sat.jpg
#   inflating: train/273274_mask.png
#   inflating: train/273274_sat.jpg
#   inflating: train/27460_mask.png
#   inflating: train/27460_sat.jpg
#   inflating: train/276761_mask.png
#   inflating: train/276761_sat.jpg
#   inflating: train/276912_mask.png
#   inflating: train/276912_sat.jpg
#   inflating: train/277049_mask.png
#   inflating: train/277049_sat.jpg
#   inflating: train/2774_mask.png
#   inflating: train/2774_sat.jpg
#   inflating: train/277644_mask.png
#   inflating: train/277644_sat.jpg
#   inflating: train/277900_mask.png
#   inflating: train/277900_sat.jpg
#   inflating: train/277994_mask.png
#   inflating: train/277994_sat.jpg
#   inflating: train/280703_mask.png
#   inflating: train/280703_sat.jpg
#   inflating: train/280861_mask.png
#   inflating: train/280861_sat.jpg
#   inflating: train/282120_mask.png
#   inflating: train/282120_sat.jpg
#   inflating: train/283326_mask.png
#   inflating: train/283326_sat.jpg
#   inflating: train/28559_mask.png
#   inflating: train/28559_sat.jpg
#   inflating: train/286339_mask.png
#   inflating: train/286339_sat.jpg
#   inflating: train/28689_mask.png
#   inflating: train/28689_sat.jpg
#   inflating: train/28935_mask.png
#   inflating: train/28935_sat.jpg
#   inflating: train/291214_mask.png
#   inflating: train/291214_sat.jpg
#   inflating: train/291781_mask.png
#   inflating: train/291781_sat.jpg
#   inflating: train/293776_mask.png
#   inflating: train/293776_sat.jpg
#   inflating: train/29419_mask.png
#   inflating: train/29419_sat.jpg
#   inflating: train/294697_mask.png
#   inflating: train/294697_sat.jpg
#   inflating: train/294978_mask.png
#   inflating: train/294978_sat.jpg
#   inflating: train/296279_mask.png
#   inflating: train/296279_sat.jpg
#   inflating: train/296368_mask.png
#   inflating: train/296368_sat.jpg
#   inflating: train/298396_mask.png
#   inflating: train/298396_sat.jpg
#   inflating: train/298817_mask.png
#   inflating: train/298817_sat.jpg
#   inflating: train/299287_mask.png
#   inflating: train/299287_sat.jpg
#   inflating: train/300626_mask.png
#   inflating: train/300626_sat.jpg
#   inflating: train/300745_mask.png
#   inflating: train/300745_sat.jpg
#   inflating: train/300967_mask.png
#   inflating: train/300967_sat.jpg
#   inflating: train/303327_mask.png
#   inflating: train/303327_sat.jpg
#   inflating: train/306486_mask.png
#   inflating: train/306486_sat.jpg
#   inflating: train/307626_mask.png
#   inflating: train/307626_sat.jpg
#   inflating: train/308959_mask.png
#   inflating: train/308959_sat.jpg
#   inflating: train/309818_mask.png
#   inflating: train/309818_sat.jpg
#   inflating: train/310419_mask.png
#   inflating: train/310419_sat.jpg
#   inflating: train/311386_mask.png
#   inflating: train/311386_sat.jpg
#   inflating: train/312676_mask.png
#   inflating: train/312676_sat.jpg
#   inflating: train/315352_mask.png
#   inflating: train/315352_sat.jpg
#   inflating: train/315848_mask.png
#   inflating: train/315848_sat.jpg
#   inflating: train/316446_mask.png
#   inflating: train/316446_sat.jpg
#   inflating: train/318338_mask.png
#   inflating: train/318338_sat.jpg
#   inflating: train/321711_mask.png
#   inflating: train/321711_sat.jpg
#   inflating: train/321724_mask.png
#   inflating: train/321724_sat.jpg
#   inflating: train/322400_mask.png
#   inflating: train/322400_sat.jpg
#   inflating: train/323581_mask.png
#   inflating: train/323581_sat.jpg
#   inflating: train/324170_mask.png
#   inflating: train/324170_sat.jpg
#   inflating: train/325354_mask.png
#   inflating: train/325354_sat.jpg
#   inflating: train/326173_mask.png
#   inflating: train/326173_sat.jpg
#   inflating: train/326238_mask.png
#   inflating: train/326238_sat.jpg
#   inflating: train/329017_mask.png
#   inflating: train/329017_sat.jpg
#   inflating: train/330838_mask.png
#   inflating: train/330838_sat.jpg
#   inflating: train/331421_mask.png
#   inflating: train/331421_sat.jpg
#   inflating: train/331533_mask.png
#   inflating: train/331533_sat.jpg
#   inflating: train/331994_mask.png
#   inflating: train/331994_sat.jpg
#   inflating: train/332354_mask.png
#   inflating: train/332354_sat.jpg
#   inflating: train/33262_mask.png
#   inflating: train/33262_sat.jpg
#   inflating: train/333661_mask.png
#   inflating: train/333661_sat.jpg
#   inflating: train/334677_mask.png
#   inflating: train/334677_sat.jpg
#   inflating: train/334811_mask.png
#   inflating: train/334811_sat.jpg
#   inflating: train/33573_mask.png
#   inflating: train/33573_sat.jpg
#   inflating: train/335737_mask.png
#   inflating: train/335737_sat.jpg
#   inflating: train/337272_mask.png
#   inflating: train/337272_sat.jpg
#   inflating: train/338111_mask.png
#   inflating: train/338111_sat.jpg
#   inflating: train/338661_mask.png
#   inflating: train/338661_sat.jpg
#   inflating: train/338798_mask.png
#   inflating: train/338798_sat.jpg
#   inflating: train/340798_mask.png
#   inflating: train/340798_sat.jpg
#   inflating: train/340898_mask.png
#   inflating: train/340898_sat.jpg
#   inflating: train/343016_mask.png
#   inflating: train/343016_sat.jpg
#   inflating: train/343215_mask.png
#   inflating: train/343215_sat.jpg
#   inflating: train/34330_mask.png
#   inflating: train/34330_sat.jpg
#   inflating: train/343425_mask.png
#   inflating: train/343425_sat.jpg
#   inflating: train/34359_mask.png
#   inflating: train/34359_sat.jpg
#   inflating: train/345134_mask.png
#   inflating: train/345134_sat.jpg
#   inflating: train/345494_mask.png
#   inflating: train/345494_sat.jpg
#   inflating: train/34567_mask.png
#   inflating: train/34567_sat.jpg
#   inflating: train/347676_mask.png
#   inflating: train/347676_sat.jpg
#   inflating: train/347725_mask.png
#   inflating: train/347725_sat.jpg
#   inflating: train/3484_mask.png
#   inflating: train/3484_sat.jpg
#   inflating: train/349442_mask.png
#   inflating: train/349442_sat.jpg
#   inflating: train/350033_mask.png
#   inflating: train/350033_sat.jpg
#   inflating: train/350328_mask.png
#   inflating: train/350328_sat.jpg
#   inflating: train/351228_mask.png
#   inflating: train/351228_sat.jpg
#   inflating: train/351271_mask.png
#   inflating: train/351271_sat.jpg
#   inflating: train/351727_mask.png
#   inflating: train/351727_sat.jpg
#   inflating: train/352808_mask.png
#   inflating: train/352808_sat.jpg
#   inflating: train/354033_mask.png
#   inflating: train/354033_sat.jpg
#   inflating: train/358314_mask.png
#   inflating: train/358314_sat.jpg
#   inflating: train/358464_mask.png
#   inflating: train/358464_sat.jpg
#   inflating: train/358591_mask.png
#   inflating: train/358591_sat.jpg
#   inflating: train/361129_mask.png
#   inflating: train/361129_sat.jpg
#   inflating: train/36183_mask.png
#   inflating: train/36183_sat.jpg
#   inflating: train/362191_mask.png
#   inflating: train/362191_sat.jpg
#   inflating: train/362274_mask.png
#   inflating: train/362274_sat.jpg
#   inflating: train/365555_mask.png
#   inflating: train/365555_sat.jpg
#   inflating: train/373103_mask.png
#   inflating: train/373103_sat.jpg
#   inflating: train/373186_mask.png
#   inflating: train/373186_sat.jpg
#   inflating: train/375563_mask.png
#   inflating: train/375563_sat.jpg
#   inflating: train/37586_mask.png
#   inflating: train/37586_sat.jpg
#   inflating: train/376441_mask.png
#   inflating: train/376441_sat.jpg
#   inflating: train/37755_mask.png
#   inflating: train/37755_sat.jpg
#   inflating: train/382428_mask.png
#   inflating: train/382428_sat.jpg
#   inflating: train/383392_mask.png
#   inflating: train/383392_sat.jpg
#   inflating: train/383637_mask.png
#   inflating: train/383637_sat.jpg
#   inflating: train/384477_mask.png
#   inflating: train/384477_sat.jpg
#   inflating: train/387018_mask.png
#   inflating: train/387018_sat.jpg
#   inflating: train/387554_mask.png
#   inflating: train/387554_sat.jpg
#   inflating: train/388811_mask.png
#   inflating: train/388811_sat.jpg
#   inflating: train/392711_mask.png
#   inflating: train/392711_sat.jpg
#   inflating: train/393043_mask.png
#   inflating: train/393043_sat.jpg
#   inflating: train/394500_mask.png
#   inflating: train/394500_sat.jpg
#   inflating: train/396979_mask.png
#   inflating: train/396979_sat.jpg
#   inflating: train/397137_mask.png
#   inflating: train/397137_sat.jpg
#   inflating: train/397351_mask.png
#   inflating: train/397351_sat.jpg
#   inflating: train/397864_mask.png
#   inflating: train/397864_sat.jpg
#   inflating: train/400179_mask.png
#   inflating: train/400179_sat.jpg
#   inflating: train/40168_mask.png
#   inflating: train/40168_sat.jpg
#   inflating: train/402002_mask.png
#   inflating: train/402002_sat.jpg
#   inflating: train/402209_mask.png
#   inflating: train/402209_sat.jpg
#   inflating: train/40350_mask.png
#   inflating: train/40350_sat.jpg
#   inflating: train/403978_mask.png
#   inflating: train/403978_sat.jpg
#   inflating: train/405378_mask.png
#   inflating: train/405378_sat.jpg
#   inflating: train/405744_mask.png
#   inflating: train/405744_sat.jpg
#   inflating: train/406425_mask.png
#   inflating: train/406425_sat.jpg
#   inflating: train/407467_mask.png
#   inflating: train/407467_sat.jpg
#   inflating: train/411741_mask.png
#   inflating: train/411741_sat.jpg
#   inflating: train/412210_mask.png
#   inflating: train/412210_sat.jpg
#   inflating: train/413779_mask.png
#   inflating: train/413779_sat.jpg
#   inflating: train/416381_mask.png
#   inflating: train/416381_sat.jpg
#   inflating: train/416463_mask.png
#   inflating: train/416463_sat.jpg
#   inflating: train/416794_mask.png
#   inflating: train/416794_sat.jpg
#   inflating: train/417313_mask.png
#   inflating: train/417313_sat.jpg
#   inflating: train/418261_mask.png
#   inflating: train/418261_sat.jpg
#   inflating: train/41944_mask.png
#   inflating: train/41944_sat.jpg
#   inflating: train/419820_mask.png
#   inflating: train/419820_sat.jpg
#   inflating: train/420066_mask.png
#   inflating: train/420066_sat.jpg
#   inflating: train/420078_mask.png
#   inflating: train/420078_sat.jpg
#   inflating: train/423117_mask.png
#   inflating: train/423117_sat.jpg
#   inflating: train/424590_mask.png
#   inflating: train/424590_sat.jpg
#   inflating: train/427037_mask.png
#   inflating: train/427037_sat.jpg
#   inflating: train/427774_mask.png
#   inflating: train/427774_sat.jpg
#   inflating: train/428327_mask.png
#   inflating: train/428327_sat.jpg
#   inflating: train/428597_mask.png
#   inflating: train/428597_sat.jpg
#   inflating: train/428841_mask.png
#   inflating: train/428841_sat.jpg
#   inflating: train/430587_mask.png
#   inflating: train/430587_sat.jpg
#   inflating: train/432089_mask.png
#   inflating: train/432089_sat.jpg
#   inflating: train/434210_mask.png
#   inflating: train/434210_sat.jpg
#   inflating: train/434243_mask.png
#   inflating: train/434243_sat.jpg
#   inflating: train/435277_mask.png
#   inflating: train/435277_sat.jpg
#   inflating: train/437963_mask.png
#   inflating: train/437963_sat.jpg
#   inflating: train/43814_mask.png
#   inflating: train/43814_sat.jpg
#   inflating: train/438721_mask.png
#   inflating: train/438721_sat.jpg
#   inflating: train/439854_mask.png
#   inflating: train/439854_sat.jpg
#   inflating: train/44070_mask.png
#   inflating: train/44070_sat.jpg
#   inflating: train/442329_mask.png
#   inflating: train/442329_sat.jpg
#   inflating: train/442338_mask.png
#   inflating: train/442338_sat.jpg
#   inflating: train/443271_mask.png
#   inflating: train/443271_sat.jpg
#   inflating: train/444902_mask.png
#   inflating: train/444902_sat.jpg
#   inflating: train/449319_mask.png
#   inflating: train/449319_sat.jpg
#   inflating: train/45357_mask.png
#   inflating: train/45357_sat.jpg
#   inflating: train/454655_mask.png
#   inflating: train/454655_sat.jpg
#   inflating: train/455374_mask.png
#   inflating: train/455374_sat.jpg
#   inflating: train/45676_mask.png
#   inflating: train/45676_sat.jpg
#   inflating: train/457070_mask.png
#   inflating: train/457070_sat.jpg
#   inflating: train/457265_mask.png
#   inflating: train/457265_sat.jpg
#   inflating: train/457982_mask.png
#   inflating: train/457982_sat.jpg
#   inflating: train/458687_mask.png
#   inflating: train/458687_sat.jpg
#   inflating: train/458776_mask.png
#   inflating: train/458776_sat.jpg
#   inflating: train/461001_mask.png
#   inflating: train/461001_sat.jpg
#   inflating: train/461755_mask.png
#   inflating: train/461755_sat.jpg
#   inflating: train/462612_mask.png
#   inflating: train/462612_sat.jpg
#   inflating: train/463855_mask.png
#   inflating: train/463855_sat.jpg
#   inflating: train/467076_mask.png
#   inflating: train/467076_sat.jpg
#   inflating: train/467855_mask.png
#   inflating: train/467855_sat.jpg
#   inflating: train/468103_mask.png
#   inflating: train/468103_sat.jpg
#   inflating: train/470446_mask.png
#   inflating: train/470446_sat.jpg
#   inflating: train/470798_mask.png
#   inflating: train/470798_sat.jpg
#   inflating: train/471187_mask.png
#   inflating: train/471187_sat.jpg
#   inflating: train/471930_mask.png
#   inflating: train/471930_sat.jpg
#   inflating: train/472774_mask.png
#   inflating: train/472774_sat.jpg
#   inflating: train/476582_mask.png
#   inflating: train/476582_sat.jpg
#   inflating: train/476991_mask.png
#   inflating: train/476991_sat.jpg
#   inflating: train/479682_mask.png
#   inflating: train/479682_sat.jpg
#   inflating: train/482365_mask.png
#   inflating: train/482365_sat.jpg
#   inflating: train/483506_mask.png
#   inflating: train/483506_sat.jpg
#   inflating: train/485061_mask.png
#   inflating: train/485061_sat.jpg
#   inflating: train/491356_mask.png
#   inflating: train/491356_sat.jpg
#   inflating: train/491491_mask.png
#   inflating: train/491491_sat.jpg
#   inflating: train/491696_mask.png
#   inflating: train/491696_sat.jpg
#   inflating: train/492365_mask.png
#   inflating: train/492365_sat.jpg
#   inflating: train/495406_mask.png
#   inflating: train/495406_sat.jpg
#   inflating: train/495876_mask.png
#   inflating: train/495876_sat.jpg
#   inflating: train/496948_mask.png
#   inflating: train/496948_sat.jpg
#   inflating: train/498049_mask.png
#   inflating: train/498049_sat.jpg
#   inflating: train/499161_mask.png
#   inflating: train/499161_sat.jpg
#   inflating: train/499266_mask.png
#   inflating: train/499266_sat.jpg
#   inflating: train/499325_mask.png
#   inflating: train/499325_sat.jpg
#   inflating: train/499418_mask.png
#   inflating: train/499418_sat.jpg
#   inflating: train/499511_mask.png
#   inflating: train/499511_sat.jpg
#   inflating: train/499600_mask.png
#   inflating: train/499600_sat.jpg
#   inflating: train/501053_mask.png
#   inflating: train/501053_sat.jpg
#   inflating: train/501284_mask.png
#   inflating: train/501284_sat.jpg
#   inflating: train/501804_mask.png
#   inflating: train/501804_sat.jpg
#   inflating: train/503968_mask.png
#   inflating: train/503968_sat.jpg
#   inflating: train/504704_mask.png
#   inflating: train/504704_sat.jpg
#   inflating: train/505217_mask.png
#   inflating: train/505217_sat.jpg
#   inflating: train/507241_mask.png
#   inflating: train/507241_sat.jpg
#   inflating: train/508571_mask.png
#   inflating: train/508571_sat.jpg
#   inflating: train/508676_mask.png
#   inflating: train/508676_sat.jpg
#   inflating: train/509290_mask.png
#   inflating: train/509290_sat.jpg
#   inflating: train/511850_mask.png
#   inflating: train/511850_sat.jpg
#   inflating: train/512669_mask.png
#   inflating: train/512669_sat.jpg
#   inflating: train/513585_mask.png
#   inflating: train/513585_sat.jpg
#   inflating: train/513968_mask.png
#   inflating: train/513968_sat.jpg
#   inflating: train/514385_mask.png
#   inflating: train/514385_sat.jpg
#   inflating: train/514414_mask.png
#   inflating: train/514414_sat.jpg
#   inflating: train/515521_mask.png
#   inflating: train/515521_sat.jpg
#   inflating: train/516056_mask.png
#   inflating: train/516056_sat.jpg
#   inflating: train/516317_mask.png
#   inflating: train/516317_sat.jpg
#   inflating: train/518833_mask.png
#   inflating: train/518833_sat.jpg
#   inflating: train/51911_mask.png
#   inflating: train/51911_sat.jpg
#   inflating: train/520614_mask.png
#   inflating: train/520614_sat.jpg
#   inflating: train/524056_mask.png
#   inflating: train/524056_sat.jpg
#   inflating: train/524518_mask.png
#   inflating: train/524518_sat.jpg
#   inflating: train/525105_mask.png
#   inflating: train/525105_sat.jpg
#   inflating: train/528163_mask.png
#   inflating: train/528163_sat.jpg
#   inflating: train/530040_mask.png
#   inflating: train/530040_sat.jpg
#   inflating: train/533948_mask.png
#   inflating: train/533948_sat.jpg
#   inflating: train/533952_mask.png
#   inflating: train/533952_sat.jpg
#   inflating: train/534154_mask.png
#   inflating: train/534154_sat.jpg
#   inflating: train/536496_mask.png
#   inflating: train/536496_sat.jpg
#   inflating: train/537221_mask.png
#   inflating: train/537221_sat.jpg
#   inflating: train/538243_mask.png
#   inflating: train/538243_sat.jpg
#   inflating: train/538922_mask.png
#   inflating: train/538922_sat.jpg
#   inflating: train/53987_mask.png
#   inflating: train/53987_sat.jpg
#   inflating: train/541060_mask.png
#   inflating: train/541060_sat.jpg
#   inflating: train/541353_mask.png
#   inflating: train/541353_sat.jpg
#   inflating: train/543806_mask.png
#   inflating: train/543806_sat.jpg
#   inflating: train/544078_mask.png
#   inflating: train/544078_sat.jpg
#   inflating: train/544464_mask.png
#   inflating: train/544464_sat.jpg
#   inflating: train/544537_mask.png
#   inflating: train/544537_sat.jpg
#   inflating: train/547080_mask.png
#   inflating: train/547080_sat.jpg
#   inflating: train/547201_mask.png
#   inflating: train/547201_sat.jpg
#   inflating: train/547785_mask.png
#   inflating: train/547785_sat.jpg
#   inflating: train/548423_mask.png
#   inflating: train/548423_sat.jpg
#   inflating: train/548686_mask.png
#   inflating: train/548686_sat.jpg
#   inflating: train/549870_mask.png
#   inflating: train/549870_sat.jpg
#   inflating: train/549959_mask.png
#   inflating: train/549959_sat.jpg
#   inflating: train/550312_mask.png
#   inflating: train/550312_sat.jpg
#   inflating: train/552001_mask.png
#   inflating: train/552001_sat.jpg
#   inflating: train/552206_mask.png
#   inflating: train/552206_sat.jpg
#   inflating: train/552396_mask.png
#   inflating: train/552396_sat.jpg
#   inflating: train/55374_mask.png
#   inflating: train/55374_sat.jpg
#   inflating: train/556452_mask.png
#   inflating: train/556452_sat.jpg
#   inflating: train/556572_mask.png
#   inflating: train/556572_sat.jpg
#   inflating: train/557175_mask.png
#   inflating: train/557175_sat.jpg
#   inflating: train/557309_mask.png
#   inflating: train/557309_sat.jpg
#   inflating: train/557439_mask.png
#   inflating: train/557439_sat.jpg
#   inflating: train/559477_mask.png
#   inflating: train/559477_sat.jpg
#   inflating: train/560353_mask.png
#   inflating: train/560353_sat.jpg
#   inflating: train/561117_mask.png
#   inflating: train/561117_sat.jpg
#   inflating: train/563092_mask.png
#   inflating: train/563092_sat.jpg
#   inflating: train/565914_mask.png
#   inflating: train/565914_sat.jpg
#   inflating: train/568270_mask.png
#   inflating: train/568270_sat.jpg
#   inflating: train/56924_mask.png
#   inflating: train/56924_sat.jpg
#   inflating: train/570332_mask.png
#   inflating: train/570332_sat.jpg
#   inflating: train/570992_mask.png
#   inflating: train/570992_sat.jpg
#   inflating: train/571520_mask.png
#   inflating: train/571520_sat.jpg
#   inflating: train/572237_mask.png
#   inflating: train/572237_sat.jpg
#   inflating: train/574789_mask.png
#   inflating: train/574789_sat.jpg
#   inflating: train/575902_mask.png
#   inflating: train/575902_sat.jpg
#   inflating: train/576417_mask.png
#   inflating: train/576417_sat.jpg
#   inflating: train/577164_mask.png
#   inflating: train/577164_sat.jpg
#   inflating: train/584663_mask.png
#   inflating: train/584663_sat.jpg
#   inflating: train/584712_mask.png
#   inflating: train/584712_sat.jpg
#   inflating: train/584865_mask.png
#   inflating: train/584865_sat.jpg
#   inflating: train/584941_mask.png
#   inflating: train/584941_sat.jpg
#   inflating: train/585043_mask.png
#   inflating: train/585043_sat.jpg
#   inflating: train/586222_mask.png
#   inflating: train/586222_sat.jpg
#   inflating: train/586670_mask.png
#   inflating: train/586670_sat.jpg
#   inflating: train/586806_mask.png
#   inflating: train/586806_sat.jpg
#   inflating: train/587968_mask.png
#   inflating: train/587968_sat.jpg
#   inflating: train/588542_mask.png
#   inflating: train/588542_sat.jpg
#   inflating: train/58864_mask.png
#   inflating: train/58864_sat.jpg
#   inflating: train/58910_mask.png
#   inflating: train/58910_sat.jpg
#   inflating: train/589940_mask.png
#   inflating: train/589940_sat.jpg
#   inflating: train/591815_mask.png
#   inflating: train/591815_sat.jpg
#   inflating: train/596837_mask.png
#   inflating: train/596837_sat.jpg
#   inflating: train/599743_mask.png
#   inflating: train/599743_sat.jpg
#   inflating: train/599842_mask.png
#   inflating: train/599842_sat.jpg
#   inflating: train/599975_mask.png
#   inflating: train/599975_sat.jpg
#   inflating: train/600230_mask.png
#   inflating: train/600230_sat.jpg
#   inflating: train/601966_mask.png
#   inflating: train/601966_sat.jpg
#   inflating: train/602453_mask.png
#   inflating: train/602453_sat.jpg
#   inflating: train/603617_mask.png
#   inflating: train/603617_sat.jpg
#   inflating: train/604647_mask.png
#   inflating: train/604647_sat.jpg
#   inflating: train/604833_mask.png
#   inflating: train/604833_sat.jpg
#   inflating: train/605037_mask.png
#   inflating: train/605037_sat.jpg
#   inflating: train/605707_mask.png
#   inflating: train/605707_sat.jpg
#   inflating: train/605764_mask.png
#   inflating: train/605764_sat.jpg
#   inflating: train/606_mask.png
#   inflating: train/606_sat.jpg
#   inflating: train/606014_mask.png
#   inflating: train/606014_sat.jpg
#   inflating: train/606370_mask.png
#   inflating: train/606370_sat.jpg
#   inflating: train/607622_mask.png
#   inflating: train/607622_sat.jpg
#   inflating: train/608673_mask.png
#   inflating: train/608673_sat.jpg
#   inflating: train/609234_mask.png
#   inflating: train/609234_sat.jpg
#   inflating: train/611015_mask.png
#   inflating: train/611015_sat.jpg
#   inflating: train/612214_mask.png
#   inflating: train/612214_sat.jpg
#   inflating: train/61245_mask.png
#   inflating: train/61245_sat.jpg
#   inflating: train/613687_mask.png
#   inflating: train/613687_sat.jpg
#   inflating: train/614561_mask.png
#   inflating: train/614561_sat.jpg
#   inflating: train/615420_mask.png
#   inflating: train/615420_sat.jpg
#   inflating: train/616234_mask.png
#   inflating: train/616234_sat.jpg
#   inflating: train/616860_mask.png
#   inflating: train/616860_sat.jpg
#   inflating: train/617844_mask.png
#   inflating: train/617844_sat.jpg
#   inflating: train/618372_mask.png
#   inflating: train/618372_sat.jpg
#   inflating: train/619800_mask.png
#   inflating: train/619800_sat.jpg
#   inflating: train/620018_mask.png
#   inflating: train/620018_sat.jpg
#   inflating: train/62078_mask.png
#   inflating: train/62078_sat.jpg
#   inflating: train/621206_mask.png
#   inflating: train/621206_sat.jpg
#   inflating: train/621459_mask.png
#   inflating: train/621459_sat.jpg
#   inflating: train/621633_mask.png
#   inflating: train/621633_sat.jpg
#   inflating: train/622733_mask.png
#   inflating: train/622733_sat.jpg
#   inflating: train/623857_mask.png
#   inflating: train/623857_sat.jpg
#   inflating: train/624916_mask.png
#   inflating: train/624916_sat.jpg
#   inflating: train/625296_mask.png
#   inflating: train/625296_sat.jpg
#   inflating: train/626208_mask.png
#   inflating: train/626208_sat.jpg
#   inflating: train/626323_mask.png
#   inflating: train/626323_sat.jpg
#   inflating: train/627583_mask.png
#   inflating: train/627583_sat.jpg
#   inflating: train/627806_mask.png
#   inflating: train/627806_sat.jpg
#   inflating: train/628479_mask.png
#   inflating: train/628479_sat.jpg
#   inflating: train/629198_mask.png
#   inflating: train/629198_sat.jpg
#   inflating: train/632489_mask.png
#   inflating: train/632489_sat.jpg
#   inflating: train/634421_mask.png
#   inflating: train/634421_sat.jpg
#   inflating: train/634717_mask.png
#   inflating: train/634717_sat.jpg
#   inflating: train/635157_mask.png
#   inflating: train/635157_sat.jpg
#   inflating: train/635841_mask.png
#   inflating: train/635841_sat.jpg
#   inflating: train/636849_mask.png
#   inflating: train/636849_sat.jpg
#   inflating: train/638158_mask.png
#   inflating: train/638158_sat.jpg
#   inflating: train/638168_mask.png
#   inflating: train/638168_sat.jpg
#   inflating: train/638937_mask.png
#   inflating: train/638937_sat.jpg
#   inflating: train/639004_mask.png
#   inflating: train/639004_sat.jpg
#   inflating: train/639149_mask.png
#   inflating: train/639149_sat.jpg
#   inflating: train/639314_mask.png
#   inflating: train/639314_sat.jpg
#   inflating: train/6399_mask.png
#   inflating: train/6399_sat.jpg
#   inflating: train/641771_mask.png
#   inflating: train/641771_sat.jpg
#   inflating: train/642909_mask.png
#   inflating: train/642909_sat.jpg
#   inflating: train/644103_mask.png
#   inflating: train/644103_sat.jpg
#   inflating: train/644150_mask.png
#   inflating: train/644150_sat.jpg
#   inflating: train/645001_mask.png
#   inflating: train/645001_sat.jpg
#   inflating: train/646596_mask.png
#   inflating: train/646596_sat.jpg
#   inflating: train/649042_mask.png
#   inflating: train/649042_sat.jpg
#   inflating: train/649260_mask.png
#   inflating: train/649260_sat.jpg
#   inflating: train/650253_mask.png
#   inflating: train/650253_sat.jpg
#   inflating: train/650751_mask.png
#   inflating: train/650751_sat.jpg
#   inflating: train/651312_mask.png
#   inflating: train/651312_sat.jpg
#   inflating: train/651537_mask.png
#   inflating: train/651537_sat.jpg
#   inflating: train/65170_mask.png
#   inflating: train/65170_sat.jpg
#   inflating: train/651774_mask.png
#   inflating: train/651774_sat.jpg
#   inflating: train/652183_mask.png
#   inflating: train/652183_sat.jpg
#   inflating: train/652733_mask.png
#   inflating: train/652733_sat.jpg
#   inflating: train/652883_mask.png
#   inflating: train/652883_sat.jpg
#   inflating: train/654770_mask.png
#   inflating: train/654770_sat.jpg
#   inflating: train/655313_mask.png
#   inflating: train/655313_sat.jpg
#   inflating: train/659953_mask.png
#   inflating: train/659953_sat.jpg
#   inflating: train/660069_mask.png
#   inflating: train/660069_sat.jpg
#   inflating: train/660933_mask.png
#   inflating: train/660933_sat.jpg
#   inflating: train/661864_mask.png
#   inflating: train/661864_sat.jpg
#   inflating: train/66344_mask.png
#   inflating: train/66344_sat.jpg
#   inflating: train/664140_mask.png
#   inflating: train/664140_sat.jpg
#   inflating: train/664396_mask.png
#   inflating: train/664396_sat.jpg
#   inflating: train/665914_mask.png
#   inflating: train/665914_sat.jpg
#   inflating: train/668465_mask.png
#   inflating: train/668465_sat.jpg
#   inflating: train/669010_mask.png
#   inflating: train/669010_sat.jpg
#   inflating: train/669156_mask.png
#   inflating: train/669156_sat.jpg
#   inflating: train/669779_mask.png
#   inflating: train/669779_sat.jpg
#   inflating: train/671164_mask.png
#   inflating: train/671164_sat.jpg
#   inflating: train/672041_mask.png
#   inflating: train/672041_sat.jpg
#   inflating: train/672823_mask.png
#   inflating: train/672823_sat.jpg
#   inflating: train/673927_mask.png
#   inflating: train/673927_sat.jpg
#   inflating: train/675424_mask.png
#   inflating: train/675424_sat.jpg
#   inflating: train/675849_mask.png
#   inflating: train/675849_sat.jpg
#   inflating: train/676758_mask.png
#   inflating: train/676758_sat.jpg
#   inflating: train/678520_mask.png
#   inflating: train/678520_sat.jpg
#   inflating: train/679036_mask.png
#   inflating: train/679036_sat.jpg
#   inflating: train/679507_mask.png
#   inflating: train/679507_sat.jpg
#   inflating: train/68078_mask.png
#   inflating: train/68078_sat.jpg
#   inflating: train/682046_mask.png
#   inflating: train/682046_sat.jpg
#   inflating: train/682688_mask.png
#   inflating: train/682688_sat.jpg
#   inflating: train/682949_mask.png
#   inflating: train/682949_sat.jpg
#   inflating: train/684377_mask.png
#   inflating: train/684377_sat.jpg
#   inflating: train/686781_mask.png
#   inflating: train/686781_sat.jpg
#   inflating: train/688544_mask.png
#   inflating: train/688544_sat.jpg
#   inflating: train/691384_mask.png
#   inflating: train/691384_sat.jpg
#   inflating: train/692004_mask.png
#   inflating: train/692004_sat.jpg
#   inflating: train/692982_mask.png
#   inflating: train/692982_sat.jpg
#   inflating: train/695475_mask.png
#   inflating: train/695475_sat.jpg
#   inflating: train/696257_mask.png
#   inflating: train/696257_sat.jpg
#   inflating: train/69628_mask.png
#   inflating: train/69628_sat.jpg
#   inflating: train/698065_mask.png
#   inflating: train/698065_sat.jpg
#   inflating: train/698628_mask.png
#   inflating: train/698628_sat.jpg
#   inflating: train/699650_mask.png
#   inflating: train/699650_sat.jpg
#   inflating: train/702918_mask.png
#   inflating: train/702918_sat.jpg
#   inflating: train/703413_mask.png
#   inflating: train/703413_sat.jpg
#   inflating: train/705728_mask.png
#   inflating: train/705728_sat.jpg
#   inflating: train/706996_mask.png
#   inflating: train/706996_sat.jpg
#   inflating: train/707319_mask.png
#   inflating: train/707319_sat.jpg
#   inflating: train/708527_mask.png
#   inflating: train/708527_sat.jpg
#   inflating: train/708588_mask.png
#   inflating: train/708588_sat.jpg
#   inflating: train/71125_mask.png
#   inflating: train/71125_sat.jpg
#   inflating: train/711893_mask.png
#   inflating: train/711893_sat.jpg
#   inflating: train/713813_mask.png
#   inflating: train/713813_sat.jpg
#   inflating: train/714414_mask.png
#   inflating: train/714414_sat.jpg
#   inflating: train/715633_mask.png
#   inflating: train/715633_sat.jpg
#   inflating: train/715846_mask.png
#   inflating: train/715846_sat.jpg
#   inflating: train/71619_mask.png
#   inflating: train/71619_sat.jpg
#   inflating: train/717225_mask.png
#   inflating: train/717225_sat.jpg
#   inflating: train/723067_mask.png
#   inflating: train/723067_sat.jpg
#   inflating: train/723719_mask.png
#   inflating: train/723719_sat.jpg
#   inflating: train/725646_mask.png
#   inflating: train/725646_sat.jpg
#   inflating: train/726265_mask.png
#   inflating: train/726265_sat.jpg
#   inflating: train/727832_mask.png
#   inflating: train/727832_sat.jpg
#   inflating: train/72807_mask.png
#   inflating: train/72807_sat.jpg
#   inflating: train/728521_mask.png
#   inflating: train/728521_sat.jpg
#   inflating: train/730821_mask.png
#   inflating: train/730821_sat.jpg
#   inflating: train/730889_mask.png
#   inflating: train/730889_sat.jpg
#   inflating: train/732669_mask.png
#   inflating: train/732669_sat.jpg
#   inflating: train/733758_mask.png
#   inflating: train/733758_sat.jpg
#   inflating: train/736869_mask.png
#   inflating: train/736869_sat.jpg
#   inflating: train/736933_mask.png
#   inflating: train/736933_sat.jpg
#   inflating: train/739122_mask.png
#   inflating: train/739122_sat.jpg
#   inflating: train/739760_mask.png
#   inflating: train/739760_sat.jpg
#   inflating: train/740937_mask.png
#   inflating: train/740937_sat.jpg
#   inflating: train/741105_mask.png
#   inflating: train/741105_sat.jpg
#   inflating: train/747824_mask.png
#   inflating: train/747824_sat.jpg
#   inflating: train/748225_mask.png
#   inflating: train/748225_sat.jpg
#   inflating: train/749375_mask.png
#   inflating: train/749375_sat.jpg
#   inflating: train/749523_mask.png
#   inflating: train/749523_sat.jpg
#   inflating: train/751939_mask.png
#   inflating: train/751939_sat.jpg
#   inflating: train/753408_mask.png
#   inflating: train/753408_sat.jpg
#   inflating: train/755453_mask.png
#   inflating: train/755453_sat.jpg
#   inflating: train/757745_mask.png
#   inflating: train/757745_sat.jpg
#   inflating: train/759668_mask.png
#   inflating: train/759668_sat.jpg
#   inflating: train/759855_mask.png
#   inflating: train/759855_sat.jpg
#   inflating: train/761189_mask.png
#   inflating: train/761189_sat.jpg
#   inflating: train/762359_mask.png
#   inflating: train/762359_sat.jpg
#   inflating: train/762470_mask.png
#   inflating: train/762470_sat.jpg
#   inflating: train/762937_mask.png
#   inflating: train/762937_sat.jpg
#   inflating: train/763075_mask.png
#   inflating: train/763075_sat.jpg
#   inflating: train/763892_mask.png
#   inflating: train/763892_sat.jpg
#   inflating: train/765792_mask.png
#   inflating: train/765792_sat.jpg
#   inflating: train/767012_mask.png
#   inflating: train/767012_sat.jpg
#   inflating: train/76759_mask.png
#   inflating: train/76759_sat.jpg
#   inflating: train/768475_mask.png
#   inflating: train/768475_sat.jpg
#   inflating: train/771393_mask.png
#   inflating: train/771393_sat.jpg
#   inflating: train/772130_mask.png
#   inflating: train/772130_sat.jpg
#   inflating: train/772144_mask.png
#   inflating: train/772144_sat.jpg
#   inflating: train/772452_mask.png
#   inflating: train/772452_sat.jpg
#   inflating: train/772567_mask.png
#   inflating: train/772567_sat.jpg
#   inflating: train/77388_mask.png
#   inflating: train/77388_sat.jpg
#   inflating: train/774779_mask.png
#   inflating: train/774779_sat.jpg
#   inflating: train/775304_mask.png
#   inflating: train/775304_sat.jpg
#   inflating: train/77669_mask.png
#   inflating: train/77669_sat.jpg
#   inflating: train/777185_mask.png
#   inflating: train/777185_sat.jpg
#   inflating: train/778804_mask.png
#   inflating: train/778804_sat.jpg
#   inflating: train/7791_mask.png
#   inflating: train/7791_sat.jpg
#   inflating: train/782103_mask.png
#   inflating: train/782103_sat.jpg
#   inflating: train/78298_mask.png
#   inflating: train/78298_sat.jpg
#   inflating: train/784140_mask.png
#   inflating: train/784140_sat.jpg
#   inflating: train/78430_mask.png
#   inflating: train/78430_sat.jpg
#   inflating: train/784518_mask.png
#   inflating: train/784518_sat.jpg
#   inflating: train/786226_mask.png
#   inflating: train/786226_sat.jpg
#   inflating: train/7892_mask.png
#   inflating: train/7892_sat.jpg
#   inflating: train/79049_mask.png
#   inflating: train/79049_sat.jpg
#   inflating: train/7906_mask.png
#   inflating: train/7906_sat.jpg
#   inflating: train/794214_mask.png
#   inflating: train/794214_sat.jpg
#   inflating: train/798411_mask.png
#   inflating: train/798411_sat.jpg
#   inflating: train/799523_mask.png
#   inflating: train/799523_sat.jpg
#   inflating: train/801361_mask.png
#   inflating: train/801361_sat.jpg
#   inflating: train/802645_mask.png
#   inflating: train/802645_sat.jpg
#   inflating: train/80318_mask.png
#   inflating: train/80318_sat.jpg
#   inflating: train/803958_mask.png
#   inflating: train/803958_sat.jpg
#   inflating: train/805150_mask.png
#   inflating: train/805150_sat.jpg
#   inflating: train/806805_mask.png
#   inflating: train/806805_sat.jpg
#   inflating: train/807146_mask.png
#   inflating: train/807146_sat.jpg
#   inflating: train/80808_mask.png
#   inflating: train/80808_sat.jpg
#   inflating: train/808980_mask.png
#   inflating: train/808980_sat.jpg
#   inflating: train/81011_mask.png
#   inflating: train/81011_sat.jpg
#   inflating: train/810368_mask.png
#   inflating: train/810368_sat.jpg
#   inflating: train/81039_mask.png
#   inflating: train/81039_sat.jpg
#   inflating: train/810749_mask.png
#   inflating: train/810749_sat.jpg
#   inflating: train/811075_mask.png
#   inflating: train/811075_sat.jpg
#   inflating: train/818254_mask.png
#   inflating: train/818254_sat.jpg
#   inflating: train/819442_mask.png
#   inflating: train/819442_sat.jpg
#   inflating: train/820347_mask.png
#   inflating: train/820347_sat.jpg
#   inflating: train/820543_mask.png
#   inflating: train/820543_sat.jpg
#   inflating: train/825592_mask.png
#   inflating: train/825592_sat.jpg
#   inflating: train/825816_mask.png
#   inflating: train/825816_sat.jpg
#   inflating: train/827126_mask.png
#   inflating: train/827126_sat.jpg
#   inflating: train/828684_mask.png
#   inflating: train/828684_sat.jpg
#   inflating: train/829962_mask.png
#   inflating: train/829962_sat.jpg
#   inflating: train/830444_mask.png
#   inflating: train/830444_sat.jpg
#   inflating: train/831146_mask.png
#   inflating: train/831146_sat.jpg
#   inflating: train/834433_mask.png
#   inflating: train/834433_sat.jpg
#   inflating: train/834900_mask.png
#   inflating: train/834900_sat.jpg
#   inflating: train/835147_mask.png
#   inflating: train/835147_sat.jpg
#   inflating: train/838669_mask.png
#   inflating: train/838669_sat.jpg
#   inflating: train/838873_mask.png
#   inflating: train/838873_sat.jpg
#   inflating: train/839012_mask.png
#   inflating: train/839012_sat.jpg
#   inflating: train/839641_mask.png
#   inflating: train/839641_sat.jpg
#   inflating: train/841286_mask.png
#   inflating: train/841286_sat.jpg
#   inflating: train/841404_mask.png
#   inflating: train/841404_sat.jpg
#   inflating: train/841621_mask.png
#   inflating: train/841621_sat.jpg
#   inflating: train/842556_mask.png
#   inflating: train/842556_sat.jpg
#   inflating: train/845069_mask.png
#   inflating: train/845069_sat.jpg
#   inflating: train/847604_mask.png
#   inflating: train/847604_sat.jpg
#   inflating: train/848649_mask.png
#   inflating: train/848649_sat.jpg
#   inflating: train/848728_mask.png
#   inflating: train/848728_sat.jpg
#   inflating: train/848780_mask.png
#   inflating: train/848780_sat.jpg
#   inflating: train/849797_mask.png
#   inflating: train/849797_sat.jpg
#   inflating: train/850510_mask.png
#   inflating: train/850510_sat.jpg
#   inflating: train/853702_mask.png
#   inflating: train/853702_sat.jpg
#   inflating: train/855_mask.png
#   inflating: train/855_sat.jpg
#   inflating: train/857201_mask.png
#   inflating: train/857201_sat.jpg
#   inflating: train/858771_mask.png
#   inflating: train/858771_sat.jpg
#   inflating: train/860326_mask.png
#   inflating: train/860326_sat.jpg
#   inflating: train/861353_mask.png
#   inflating: train/861353_sat.jpg
#   inflating: train/864488_mask.png
#   inflating: train/864488_sat.jpg
#   inflating: train/866782_mask.png
#   inflating: train/866782_sat.jpg
#   inflating: train/867017_mask.png
#   inflating: train/867017_sat.jpg
#   inflating: train/867349_mask.png
#   inflating: train/867349_sat.jpg
#   inflating: train/867983_mask.png
#   inflating: train/867983_sat.jpg
#   inflating: train/868003_mask.png
#   inflating: train/868003_sat.jpg
#   inflating: train/86805_mask.png
#   inflating: train/86805_sat.jpg
#   inflating: train/870705_mask.png
#   inflating: train/870705_sat.jpg
#   inflating: train/873132_mask.png
#   inflating: train/873132_sat.jpg
#   inflating: train/875327_mask.png
#   inflating: train/875327_sat.jpg
#   inflating: train/875328_mask.png
#   inflating: train/875328_sat.jpg
#   inflating: train/875409_mask.png
#   inflating: train/875409_sat.jpg
#   inflating: train/876248_mask.png
#   inflating: train/876248_sat.jpg
#   inflating: train/877160_mask.png
#   inflating: train/877160_sat.jpg
#   inflating: train/878990_mask.png
#   inflating: train/878990_sat.jpg
#   inflating: train/880610_mask.png
#   inflating: train/880610_sat.jpg
#   inflating: train/882451_mask.png
#   inflating: train/882451_sat.jpg
#   inflating: train/88571_mask.png
#   inflating: train/88571_sat.jpg
#   inflating: train/888263_mask.png
#   inflating: train/888263_sat.jpg
#   inflating: train/888343_mask.png
#   inflating: train/888343_sat.jpg
#   inflating: train/889145_mask.png
#   inflating: train/889145_sat.jpg
#   inflating: train/889920_mask.png
#   inflating: train/889920_sat.jpg
#   inflating: train/890145_mask.png
#   inflating: train/890145_sat.jpg
#   inflating: train/891153_mask.png
#   inflating: train/891153_sat.jpg
#   inflating: train/893261_mask.png
#   inflating: train/893261_sat.jpg
#   inflating: train/893651_mask.png
#   inflating: train/893651_sat.jpg
#   inflating: train/893904_mask.png
#   inflating: train/893904_sat.jpg
#   inflating: train/895509_mask.png
#   inflating: train/895509_sat.jpg
#   inflating: train/897901_mask.png
#   inflating: train/897901_sat.jpg
#   inflating: train/898741_mask.png
#   inflating: train/898741_sat.jpg
#   inflating: train/899693_mask.png
#   inflating: train/899693_sat.jpg
#   inflating: train/900985_mask.png
#   inflating: train/900985_sat.jpg
#   inflating: train/901715_mask.png
#   inflating: train/901715_sat.jpg
#   inflating: train/902350_mask.png
#   inflating: train/902350_sat.jpg
#   inflating: train/903649_mask.png
#   inflating: train/903649_sat.jpg
#   inflating: train/904606_mask.png
#   inflating: train/904606_sat.jpg
#   inflating: train/906113_mask.png
#   inflating: train/906113_sat.jpg
#   inflating: train/908837_mask.png
#   inflating: train/908837_sat.jpg
#   inflating: train/910525_mask.png
#   inflating: train/910525_sat.jpg
#   inflating: train/911457_mask.png
#   inflating: train/911457_sat.jpg
#   inflating: train/912087_mask.png
#   inflating: train/912087_sat.jpg
#   inflating: train/912620_mask.png
#   inflating: train/912620_sat.jpg
#   inflating: train/914008_mask.png
#   inflating: train/914008_sat.jpg
#   inflating: train/916141_mask.png
#   inflating: train/916141_sat.jpg
#   inflating: train/916336_mask.png
#   inflating: train/916336_sat.jpg
#   inflating: train/916518_mask.png
#   inflating: train/916518_sat.jpg
#   inflating: train/917081_mask.png
#   inflating: train/917081_sat.jpg
#   inflating: train/918105_mask.png
#   inflating: train/918105_sat.jpg
#   inflating: train/918446_mask.png
#   inflating: train/918446_sat.jpg
#   inflating: train/919051_mask.png
#   inflating: train/919051_sat.jpg
#   inflating: train/919602_mask.png
#   inflating: train/919602_sat.jpg
#   inflating: train/923223_mask.png
#   inflating: train/923223_sat.jpg
#   inflating: train/923618_mask.png
#   inflating: train/923618_sat.jpg
#   inflating: train/924236_mask.png
#   inflating: train/924236_sat.jpg
#   inflating: train/925382_mask.png
#   inflating: train/925382_sat.jpg
#   inflating: train/925425_mask.png
#   inflating: train/925425_sat.jpg
#   inflating: train/926392_mask.png
#   inflating: train/926392_sat.jpg
#   inflating: train/927126_mask.png
#   inflating: train/927126_sat.jpg
#   inflating: train/927644_mask.png
#   inflating: train/927644_sat.jpg
#   inflating: train/930028_mask.png
#   inflating: train/930028_sat.jpg
#   inflating: train/930491_mask.png
#   inflating: train/930491_sat.jpg
#   inflating: train/934795_mask.png
#   inflating: train/934795_sat.jpg
#   inflating: train/935193_mask.png
#   inflating: train/935193_sat.jpg
#   inflating: train/935318_mask.png
#   inflating: train/935318_sat.jpg
#   inflating: train/937922_mask.png
#   inflating: train/937922_sat.jpg
#   inflating: train/939614_mask.png
#   inflating: train/939614_sat.jpg
#   inflating: train/940229_mask.png
#   inflating: train/940229_sat.jpg
#   inflating: train/941237_mask.png
#   inflating: train/941237_sat.jpg
#   inflating: train/942307_mask.png
#   inflating: train/942307_sat.jpg
#   inflating: train/942594_mask.png
#   inflating: train/942594_sat.jpg
#   inflating: train/942986_mask.png
#   inflating: train/942986_sat.jpg
#   inflating: train/943463_mask.png
#   inflating: train/943463_sat.jpg
#   inflating: train/943943_mask.png
#   inflating: train/943943_sat.jpg
#   inflating: train/946386_mask.png
#   inflating: train/946386_sat.jpg
#   inflating: train/946408_mask.png
#   inflating: train/946408_sat.jpg
#   inflating: train/946475_mask.png
#   inflating: train/946475_sat.jpg
#   inflating: train/947994_mask.png
#   inflating: train/947994_sat.jpg
#   inflating: train/949235_mask.png
#   inflating: train/949235_sat.jpg
#   inflating: train/949559_mask.png
#   inflating: train/949559_sat.jpg
#   inflating: train/950926_mask.png
#   inflating: train/950926_sat.jpg
#   inflating: train/951120_mask.png
#   inflating: train/951120_sat.jpg
#   inflating: train/952430_mask.png
#   inflating: train/952430_sat.jpg
#   inflating: train/954552_mask.png
#   inflating: train/954552_sat.jpg
#   inflating: train/95613_mask.png
#   inflating: train/95613_sat.jpg
#   inflating: train/956410_mask.png
#   inflating: train/956410_sat.jpg
#   inflating: train/95683_mask.png
#   inflating: train/95683_sat.jpg
#   inflating: train/956928_mask.png
#   inflating: train/956928_sat.jpg
#   inflating: train/958243_mask.png
#   inflating: train/958243_sat.jpg
#   inflating: train/958443_mask.png
#   inflating: train/958443_sat.jpg
#   inflating: train/95863_mask.png
#   inflating: train/95863_sat.jpg
#   inflating: train/961407_mask.png
#   inflating: train/961407_sat.jpg
#   inflating: train/961919_mask.png
#   inflating: train/961919_sat.jpg
#   inflating: train/965276_mask.png
#   inflating: train/965276_sat.jpg
#   inflating: train/965977_mask.png
#   inflating: train/965977_sat.jpg
#   inflating: train/967818_mask.png
#   inflating: train/967818_sat.jpg
#   inflating: train/96841_mask.png
#   inflating: train/96841_sat.jpg
#   inflating: train/96870_mask.png
#   inflating: train/96870_sat.jpg
#   inflating: train/969934_mask.png
#   inflating: train/969934_sat.jpg
#   inflating: train/970925_mask.png
#   inflating: train/970925_sat.jpg
#   inflating: train/971880_mask.png
#   inflating: train/971880_sat.jpg
#   inflating: train/97337_mask.png
#   inflating: train/97337_sat.jpg
#   inflating: train/978039_mask.png
#   inflating: train/978039_sat.jpg
#   inflating: train/981253_mask.png
#   inflating: train/981253_sat.jpg
#   inflating: train/98150_mask.png
#   inflating: train/98150_sat.jpg
#   inflating: train/981852_mask.png
#   inflating: train/981852_sat.jpg
#   inflating: train/982744_mask.png
#   inflating: train/982744_sat.jpg
#   inflating: train/983603_mask.png
#   inflating: train/983603_sat.jpg
#   inflating: train/986342_mask.png
#   inflating: train/986342_sat.jpg
#   inflating: train/987079_mask.png
#   inflating: train/987079_sat.jpg
#   inflating: train/987381_mask.png
#   inflating: train/987381_sat.jpg
#   inflating: train/987427_mask.png
#   inflating: train/987427_sat.jpg
#   inflating: train/988517_mask.png
#   inflating: train/988517_sat.jpg
#   inflating: train/989499_mask.png
#   inflating: train/989499_sat.jpg
#   inflating: train/990573_mask.png
#   inflating: train/990573_sat.jpg
#   inflating: train/990617_mask.png
#   inflating: train/990617_sat.jpg
#   inflating: train/990619_mask.png
#   inflating: train/990619_sat.jpg
#   inflating: train/991758_mask.png
#   inflating: train/991758_sat.jpg
#   inflating: train/992507_mask.png
#   inflating: train/992507_sat.jpg
#   inflating: train/994520_mask.png
#   inflating: train/994520_sat.jpg
#   inflating: train/995492_mask.png
#   inflating: train/995492_sat.jpg
#   inflating: train/997521_mask.png
#   inflating: train/997521_sat.jpg
#   inflating: train/998002_mask.png
#   inflating: train/998002_sat.jpg

# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# Load the metadata
metadata_path = "metadata.csv"

metadata = pd.read_csv(metadata_path)
metadata.isna().sum()
# Out:
# image_id            0
# split               0
# sat_image_path      0
# mask_path         343
# dtype: int64

# %%
metadata.shape
# Out:
# (1146, 4)

# %%
metadata.head()
# Out:
#    image_id  split        sat_image_path              mask_path
# 0    100694  train  train/100694_sat.jpg  train/100694_mask.png
# 1    102122  train  train/102122_sat.jpg  train/102122_mask.png
# 2     10233  train   train/10233_sat.jpg   train/10233_mask.png
# 3    103665  train  train/103665_sat.jpg  train/103665_mask.png
# 4    103730  train  train/103730_sat.jpg  train/103730_mask.png

# %%
metadata.split.unique()
# Out:
# array(['train', 'valid', 'test'], dtype=object)

# %%
class_dict_path = "class_dict.csv"
class_dict = pd.read_csv(class_dict_path)
class_dict
# Out:
#                name    r    g    b
# 0        urban_land    0  255  255
# 1  agriculture_land  255  255    0
# 2         rangeland  255    0  255
# 3       forest_land    0  255    0
# 4             water    0    0  255
# 5       barren_land  255  255  255
# 6           unknown    0    0    0

# %%
class_dict.dtypes
# Out:
# name    object
# r        int64
# g        int64
# b        int64
# dtype: object

# %%
# Create a mapping from (r, g, b) to class index
class_map = {(row["r"], row["g"], row["b"]): idx for idx, row in class_dict.iterrows()}
class_map
# Out:
# {(0, 255, 255): 0,
#  (255, 255, 0): 1,
#  (255, 0, 255): 2,
#  (0, 255, 0): 3,
#  (0, 0, 255): 4,
#  (255, 255, 255): 5,
#  (0, 0, 0): 6}

# %%
metadata_train = metadata[metadata["split"] == "train"]
metadata_train
# Out:
#      image_id  split        sat_image_path              mask_path
# 0      100694  train  train/100694_sat.jpg  train/100694_mask.png
# 1      102122  train  train/102122_sat.jpg  train/102122_mask.png
# 2       10233  train   train/10233_sat.jpg   train/10233_mask.png
# 3      103665  train  train/103665_sat.jpg  train/103665_mask.png
# 4      103730  train  train/103730_sat.jpg  train/103730_mask.png
# ..        ...    ...                   ...                    ...
# 798    992507  train  train/992507_sat.jpg  train/992507_mask.png
# 799    994520  train  train/994520_sat.jpg  train/994520_mask.png
# 800    995492  train  train/995492_sat.jpg  train/995492_mask.png
# 801    997521  train  train/997521_sat.jpg  train/997521_mask.png
# 802    998002  train  train/998002_sat.jpg  train/998002_mask.png
#
# [803 rows x 4 columns]

# %%
metadata_train.shape
# Out:
# (803, 4)

# %%
# Initialize lists to hold images and masks
images = []
masks = []

# Set image size
img_size = (128, 128)


for idx, row in metadata_train.iterrows():
    img_path = row["sat_image_path"]
    mask_path = row["mask_path"]

    img = Image.open(img_path).resize(img_size)
    images.append(np.array(img))

    mask = Image.open(mask_path).resize(img_size, Image.NEAREST)
    mask_array = np.array(mask)

    class_indices = np.zeros((mask_array.shape[0], mask_array.shape[1]), dtype=np.uint8)
    for color, idx in class_map.items():
        color = np.array(color)  # Convert to numpy array
        match = np.all(mask_array == color, axis=-1)
        class_indices[match] = idx

    masks.append(class_indices)

# %%
# Normalize pixels to 0 to 1 range and convert to array
images = np.array(images) / 255.0
masks = np.array(masks)

# %%
print(f"Image dimensions: {images.shape}\nMask dimensions: {masks.shape}")
# Out:
# Image dimensions: (803, 128, 128, 3)
# Mask dimensions: (803, 128, 128)

# %%
# Add channel dimension to make it equal to image dimensions or it won't work for combined processing inside model.
masks = np.expand_dims(masks, axis=-1)  # -1 => as last dimension
print(f"Mask dimensions: {masks.shape}")
# Out:
# Mask dimensions: (803, 128, 128, 1)

# %%
# Split data into training and testing sets
X_train, X_val, y_train, y_val = train_test_split(images, masks, test_size=0.1, random_state=42)

# %%
X_val.shape
# Out:
# (81, 128, 128, 3)

# %%
X_train.shape
# Out:
# (722, 128, 128, 3)

# %%
num_classes = 7

# %%
# U-Net Model with VGG16 Encoder
base_model = VGG16(include_top=False, weights="imagenet", input_shape=(128, 128, 3))

# Encoder
x1 = base_model.get_layer("block1_conv2").output
x2 = base_model.get_layer("block2_conv2").output
x3 = base_model.get_layer("block3_conv3").output
x4 = base_model.get_layer("block4_conv3").output

# Bottleneck
b = Conv2D(512, (3, 3), activation="relu", padding="same")(x4)
b = Conv2D(512, (3, 3), activation="relu", padding="same")(b)

# Decoder
u1 = UpSampling2D((2, 2))(b)
u1 = concatenate([u1, x3])
u1 = Conv2D(256, (3, 3), activation="relu", padding="same")(u1)
u1 = Conv2D(256, (3, 3), activation="relu", padding="same")(u1)

u2 = UpSampling2D((2, 2))(u1)
u2 = concatenate([u2, x2])
u2 = Conv2D(128, (3, 3), activation="relu", padding="same")(u2)
u2 = Conv2D(128, (3, 3), activation="relu", padding="same")(u2)

u3 = UpSampling2D((2, 2))(u2)
u3 = concatenate([u3, x1])
u3 = Conv2D(64, (3, 3), activation="relu", padding="same")(u3)
u3 = Conv2D(64, (3, 3), activation="relu", padding="same")(u3)

outputs = Conv2D(num_classes, (1, 1), activation="softmax")(u3)

model = Model(inputs=base_model.input, outputs=outputs)

# Compile model
model.compile(optimizer=Adam(), loss=SparseCategoricalCrossentropy(), metrics=["accuracy"])

# Define callbacks
callbacks = [
    ModelCheckpoint("unet_model1.keras", save_best_only=True, monitor="val_loss"),
    EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True),
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=8,
    validation_split=0.1,
    callbacks=callbacks,
)
# Out:
# Epoch 1/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 54s 370ms/step - accuracy: 0.5079 - loss: 4.1146 - val_accuracy: 0.6068 - val_loss: 1.3018
# Epoch 2/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 138ms/step - accuracy: 0.5369 - loss: 1.3107 - val_accuracy: 0.5530 - val_loss: 1.2700
# Epoch 3/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 20s 135ms/step - accuracy: 0.5714 - loss: 1.2244 - val_accuracy: 0.6193 - val_loss: 1.1177
# Epoch 4/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 19s 122ms/step - accuracy: 0.6064 - loss: 1.1304 - val_accuracy: 0.5906 - val_loss: 1.1539
# Epoch 5/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 125ms/step - accuracy: 0.6121 - loss: 1.1291 - val_accuracy: 0.6035 - val_loss: 1.1193
# Epoch 6/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 12s 143ms/step - accuracy: 0.6456 - loss: 1.0718 - val_accuracy: 0.6440 - val_loss: 1.0280
# Epoch 7/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 19s 121ms/step - accuracy: 0.6362 - loss: 1.0332 - val_accuracy: 0.6520 - val_loss: 1.0532
# Epoch 8/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.6398 - loss: 1.0540 - val_accuracy: 0.6466 - val_loss: 1.0428
# Epoch 9/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 11s 127ms/step - accuracy: 0.6619 - loss: 0.9858 - val_accuracy: 0.6187 - val_loss: 1.1650
# Epoch 10/10
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.6767 - loss: 0.9298 - val_accuracy: 0.6981 - val_loss: 0.9145

# %%
# !cp /content/unet_model1.keras /content/drive/MyDrive/Models_1/

# %%
model = tf.keras.models.load_model("/content/drive/MyDrive/Models_1/unet_model1.keras")

# %%
# Predict on validation set
predictions = model.predict(X_val)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 4s/step

# %%
# for prediction in predictions:
#     print(prediction)
#     break
# # [8.06242526e-02 5.12124598e-01 1.50406763e-01 ... 2.82596368e-02 1.70164704e-01 1.55683961e-02]
# Out:
# [[[3.95102389e-02 7.30799973e-01 6.86219633e-02 ... 1.46425907e-02
#    1.12851530e-01 1.12744165e-03]
#   [2.85622291e-02 7.76600897e-01 7.04617649e-02 ... 3.69660999e-03
#    1.08062632e-01 3.33185599e-04]
#   [2.55714580e-02 8.33464205e-01 5.70796914e-02 ... 1.93142483e-03
#    7.36733750e-02 2.50557583e-04]
#   ...
#   [4.43218909e-02 7.44918764e-01 6.95048496e-02 ... 6.09763805e-03
#    2.97696814e-02 2.75979080e-04]
#   [8.36364105e-02 5.91731608e-01 8.14526901e-02 ... 1.22559946e-02
#    4.66749109e-02 6.89436507e-04]
#   [1.15607359e-01 5.39691865e-01 8.00342932e-02 ... 2.86478158e-02
#    5.50074205e-02 4.15504165e-03]]
#
#  [[2.43729651e-02 7.46780455e-01 9.10773054e-02 ... 7.33488658e-03
#    1.17459469e-01 4.77170659e-04]
#   [1.75089445e-02 7.72976577e-01 6.82953969e-02 ... 2.08643265e-03
#    1.33309811e-01 7.33404522e-05]
#   [1.53633859e-02 8.16121936e-01 5.23296744e-02 ... 1.61514559e-03
#    1.09584458e-01 7.06118808e-05]
#   ...
#   [1.54733639e-02 7.40321398e-01 7.85164982e-02 ... 5.05492184e-03
#    1.22054517e-02 6.21908912e-05]
#   [3.34526598e-02 6.46096945e-01 7.50290751e-02 ... 9.52342059e-03
#    2.19019279e-02 8.23596347e-05]
#   [4.38636951e-02 7.18406618e-01 5.97930141e-02 ... 1.38905430e-02
#    1.79992467e-02 5.56789164e-04]]
#
#  [[2.53171287e-02 8.17361951e-01 6.19876310e-02 ... 3.92780313e-03
#    8.00949782e-02 1.95830668e-04]
#   [1.83715448e-02 7.88695693e-01 6.82573393e-02 ... 1.61920057e-03
#    1.18850805e-01 3.66400964e-05]
#   [1.94081925e-02 8.35589051e-01 4.61933799e-02 ... 1.05757918e-03
#    9.34319645e-02 2.56726325e-05]
#   ...
#   [1.38258711e-02 7.71359563e-01 6.43720254e-02 ... 4.29699384e-03
#    9.10887681e-03 1.39859967e-05]
#   [2.70290039e-02 6.86532736e-01 6.01809472e-02 ... 6.62191259e-03
#    1.66614801e-02 1.86543039e-05]
#   [4.34057042e-02 6.92158639e-01 4.98813875e-02 ... 9.85572860e-03
#    2.21145134e-02 2.01550793e-04]]
#
#  ...
#
#  [[3.64188626e-02 8.03577662e-01 5.95968775e-02 ... 6.15401426e-03
#    6.67615384e-02 3.56786622e-04]
#   [2.63676010e-02 8.01603734e-01 6.31856546e-02 ... 2.65561789e-03
#    8.96239951e-02 5.04805794e-05]
#   [1.70575138e-02 8.33646417e-01 5.38611338e-02 ... 1.78199715e-03
#    7.57242292e-02 3.12517222e-05]
#   ...
#   [3.72178503e-03 8.84529412e-01 3.40068787e-02 ... 1.65369676e-03
#    6.77560791e-02 3.98846423e-05]
#   [5.52285789e-03 8.72772813e-01 2.62967180e-02 ... 2.39623594e-03
#    7.92350397e-02 6.52761446e-05]
#   [1.70994177e-02 8.22547674e-01 3.22583094e-02 ... 5.83725469e-03
#    9.21323895e-02 3.83853447e-04]]
#
#  [[5.01901656e-02 7.62411118e-01 5.96366636e-02 ... 9.52192210e-03
#    8.18150192e-02 5.84783615e-04]
#   [2.40185987e-02 8.16582680e-01 6.02849163e-02 ... 4.27330425e-03
#    8.08485076e-02 9.32733747e-05]
#   [1.61664020e-02 8.44473243e-01 5.59043847e-02 ... 2.97382451e-03
#    6.68007657e-02 6.90729285e-05]
#   ...
#   [5.79905743e-03 8.98271561e-01 2.83647068e-02 ... 3.20520182e-03
#    5.78915440e-02 6.15994431e-05]
#   [1.07080769e-02 8.63852501e-01 2.98498850e-02 ... 5.57383988e-03
#    7.77140930e-02 1.13501883e-04]
#   [3.21148746e-02 8.03385794e-01 4.50665168e-02 ... 1.30384471e-02
#    8.04573521e-02 8.79978063e-04]]
#
#  [[8.73372480e-02 6.37397528e-01 6.14744090e-02 ... 2.78325472e-02
#    1.17018357e-01 2.93186493e-03]
#   [5.78764379e-02 7.31431723e-01 6.02390505e-02 ... 2.29638051e-02
#    8.79113302e-02 9.64763225e-04]
#   [4.46071625e-02 7.55855143e-01 5.65427952e-02 ... 1.46707715e-02
#    9.49074253e-02 6.20855601e-04]
#   ...
#   [2.24456973e-02 8.66494417e-01 1.89749449e-02 ... 7.07469787e-03
#    7.04586804e-02 3.80759360e-04]
#   [3.58915776e-02 8.14515531e-01 2.98049431e-02 ... 1.31273037e-02
#    8.02397877e-02 5.50226716e-04]
#   [7.12065622e-02 6.36384487e-01 7.61649758e-02 ... 3.71412858e-02
#    1.25402421e-01 4.20465600e-03]]]

# %%
# Path to your original mask image
original_mask_path = '/content/train/119_mask.png'
original_image_path = '/content/train/119_sat.jpg'

# Load the original mask image
original_mask = Image.open(original_mask_path)
original_image = Image.open(original_image_path)


image = Image.open(original_mask_path).resize((128, 128))
image_array = np.array(image) / 255.0  # Normalize
image_array = np.expand_dims(image_array, axis=0)

# Make prediction
prediction = model.predict(image_array)

original_mask_array = np.array(original_mask)
original_image_array = np.array(original_image)

plt.figure(figsize=(18, 6))

# Original Image
plt.subplot(1, 3, 1)
plt.title("Original Image")
plt.imshow(original_image_array, cmap="tab20b")

# Original Mask
plt.subplot(1, 3, 2)
plt.title("Original Mask")
plt.imshow(original_mask_array, cmap="gray")

# Predicted Mask
plt.subplot(1, 3, 3)
plt.title("Predicted Mask")
plt.imshow(np.argmax(prediction[0], axis=-1))

plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
# target_green_coverage = 18.0
# forest_class_index = 3
# agriculture_class_index = 1
# barren_land_class_index = 5

# for i, prediction in enumerate(predictions):
#     # Convert your prediction to an image format
#     predicted_mask = np.argmax(prediction, axis=-1)

#     # Calculate the total number of pixels
#     total_pixels = predicted_mask.shape[0] * predicted_mask.shape[1]

#     # Calculate current green coverage
#     green_pixels = np.sum(
#         (predicted_mask == forest_class_index)
#         | (predicted_mask == agriculture_class_index)
#     )
#     current_green_coverage = (green_pixels / total_pixels) * 100

#     # If green coverage is already 18% or more, skip this image
#     if current_green_coverage >= target_green_coverage:
#         continue

#     # Make a copy of the predicted mask before modification
#     original_predicted_mask = predicted_mask.copy()

#     # Calculate the required additional green pixels
#     target_green_pixels = int((target_green_coverage / 100) * total_pixels)
#     additional_green_pixels_needed = target_green_pixels - green_pixels

#     if additional_green_pixels_needed > 0:
#         # Identify barren land pixels
#         barren_pixels = np.where(predicted_mask == barren_land_class_index)

#         # Create a mask with barren pixels set to 1 and others set to 0
#         barren_mask = np.zeros_like(predicted_mask, dtype=np.uint8)
#         barren_mask[barren_pixels] = 1

#         # Find contours of barren land areas
#         contours, _ = cv2.findContours(
#             barren_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
#         )

#         # Sort contours by area in descending order
#         contours = sorted(contours, key=cv2.contourArea, reverse=True)

#         converted_pixels = 0
#         for contour in contours:
#             if converted_pixels >= additional_green_pixels_needed:
#                 break

#             # Find the minimum enclosing circle for the contour
#             (x, y), radius = cv2.minEnclosingCircle(contour)
#             center = (int(x), int(y))
#             radius = int(radius)

#             # Determine the maximum circle size to fit the required number of pixels
#             while radius > 0 and converted_pixels < additional_green_pixels_needed:
#                 # Draw a circle with green color (agriculture)
#                 mask_with_circle = np.zeros_like(predicted_mask, dtype=np.uint8)
#                 cv2.circle(
#                     mask_with_circle, center, radius, agriculture_class_index, -1
#                 )

#                 # Calculate the number of new green pixels that would be added
#                 new_green_pixels = np.sum(mask_with_circle == agriculture_class_index)

#                 if converted_pixels + new_green_pixels > additional_green_pixels_needed:
#                     # Reduce radius to fit the exact number of required pixels
#                     radius -= 1
#                 else:
#                     # Update the predicted mask
#                     predicted_mask[mask_with_circle == agriculture_class_index] = (agriculture_class_index)
#                     converted_pixels += new_green_pixels
#                     break

#         print(f"Converted {converted_pixels} barren pixels to green in circular patterns.")

#         # Display the original and updated masks side by side for each image
#         plt.figure(figsize=(12, 6))

#         # Original predicted mask
#         plt.subplot(1, 2, 1)
#         plt.imshow(original_predicted_mask)
#         plt.title(f"Original Predicted Mask for Image {i}")

#         # Updated predicted mask with green space allocation
#         plt.subplot(1, 2, 2)
#         plt.imshow(predicted_mask)
#         plt.title(f"Updated Predicted Mask with 18% Green Coverage for Image {i}")

#         plt.show()
# Out:
# Converted 1535 barren pixels to green in circular patterns.
# Converted 431 barren pixels to green in circular patterns.
# Converted 1192 barren pixels to green in circular patterns.
# Converted 895 barren pixels to green in circular patterns.

# %%
# Define the original colors for each class
class_colors = {
    0: (0, 255, 255),  # Urban - Cyan
    1: (255, 255, 0),  # Agriculture - Yellow
    2: (255, 0, 255),  # Rangeland - Magenta
    3: (0, 255, 0),  # Forest - Green
    4: (0, 0, 255),  # Water - Blue
    5: (255, 255, 255),  # Barren - White
    6: (0, 0, 0),  # Unknown - Black
    255:(255,0,0), # allocated -red
}


# Function to convert predicted mask to original colored mask
def convert_to_color_mask(prediction, class_colors):
    color_mask = np.zeros((*prediction.shape, 3), dtype=np.uint8)
    for class_idx, color in class_colors.items():
        color_mask[prediction == class_idx] = color
    return color_mask

target_green_coverage = 18.0  # Target green coverage in percent
forest_class_index = 3  # Index for 'forest-land'
agriculture_class_index = 1  # Index for 'agriculture-land'
barren_land_class_index = 5  # Index for 'barren-land'

# Loop through each predicted mask
for i, prediction in enumerate(predictions):
    # Convert the predicted mask to class indices
    predicted_class_mask = np.argmax(prediction, axis=-1)

    # Calculate the total number of pixels
    total_pixels = predicted_class_mask.shape[0] * predicted_class_mask.shape[1]

    # Calculate current green coverage
    green_pixels = np.sum(
        (predicted_class_mask == forest_class_index)
        | (predicted_class_mask == agriculture_class_index)
    )
    current_green_coverage = (green_pixels / total_pixels) * 100

    # For green coverage less than the target
    if current_green_coverage < target_green_coverage:
        # Make a copy of the predicted mask before modification
        original_predicted_class_mask = predicted_class_mask.copy()

        # Calculate the required additional green pixels
        target_green_pixels = int((target_green_coverage / 100) * total_pixels)
        additional_green_pixels_needed = target_green_pixels - green_pixels

        if additional_green_pixels_needed > 0:
            # Identify barren land pixels
            barren_pixels = np.where(predicted_class_mask == barren_land_class_index)

            # Create a mask with barren pixels set to 1 and others set to 0
            barren_mask = np.zeros_like(predicted_class_mask, dtype=np.uint8)
            barren_mask[barren_pixels] = 1

            # Find contours of barren land areas
            contours, _ = cv2.findContours(
                barren_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE
            )

            # Sort contours by area in descending order
            contours = sorted(contours, key=cv2.contourArea, reverse=True)

            converted_pixels = 0
            for contour in contours:
                if converted_pixels >= additional_green_pixels_needed:
                    break

                # Find the minimum enclosing circle for the contour
                (x, y), radius = cv2.minEnclosingCircle(contour)
                center = (int(x), int(y))
                radius = int(radius)

                # Determine the maximum circle size to fit the required number of pixels
                while radius > 0 and converted_pixels < additional_green_pixels_needed:
                    # Draw a circle for visualization
                    mask_with_circle = np.zeros_like(
                        predicted_class_mask, dtype=np.uint8
                    )
                    cv2.circle(mask_with_circle, center, radius, 255, -1)

                    # Calculate the number of new green pixels that would be added
                    new_green_pixels = np.sum(mask_with_circle == 255)

                    if (
                        converted_pixels + new_green_pixels
                        > additional_green_pixels_needed
                    ):
                        # Reduce radius to fit the exact number of required pixels
                        radius -= 1
                    else:
                        # Update the predicted mask with the visualization circle
                        original_predicted_class_mask[mask_with_circle == 255] = 255
                        converted_pixels += new_green_pixels
                        break

        # Convert the original and updated predicted masks to color images
        original_color_mask = convert_to_color_mask(predicted_class_mask, class_colors)
        updated_color_mask = convert_to_color_mask(
            original_predicted_class_mask, class_colors
        )

        plt.figure(figsize=(12, 6))

        plt.subplot(1, 2, 1)
        plt.imshow(original_color_mask)
        plt.title(f"Predicted Mask for Image {i}")

        plt.subplot(1, 2, 2)
        plt.imshow(updated_color_mask)
        plt.title(f"Mask with Green Space Allocation (Black)")

        plt.show()
